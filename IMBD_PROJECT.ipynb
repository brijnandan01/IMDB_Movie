# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('/content/IMDB-Movie-Data.csv')

# %% [markdown]
# DISPLAY TOP 10 ROWS OF THE DATASET

# %%
data.head(10)
# Out:
#    Rank                    Title                       Genre  \
# 0     1  Guardians of the Galaxy     Action,Adventure,Sci-Fi
# 1     2               Prometheus    Adventure,Mystery,Sci-Fi
# 2     3                    Split             Horror,Thriller
# 3     4                     Sing     Animation,Comedy,Family
# 4     5            Suicide Squad    Action,Adventure,Fantasy
# 5     6           The Great Wall    Action,Adventure,Fantasy
# 6     7               La La Land          Comedy,Drama,Music
# 7     8                 Mindhorn                      Comedy
# 8     9       The Lost City of Z  Action,Adventure,Biography
# 9    10               Passengers     Adventure,Drama,Romance
#
#                                          Description              Director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# ...

# %% [markdown]
# CHECK LAST 10 ROWS OF THE DATASET

# %%
data.tail(10)
# Out:
#      Rank                           Title                     Genre  \
# 990   991  Underworld: Rise of the Lycans  Action,Adventure,Fantasy
# 991   992                Taare Zameen Par        Drama,Family,Music
# 992   993            Take Me Home Tonight      Comedy,Drama,Romance
# 993   994        Resident Evil: Afterlife   Action,Adventure,Horror
# 994   995                       Project X                    Comedy
# 995   996            Secret in Their Eyes       Crime,Drama,Mystery
# 996   997                 Hostel: Part II                    Horror
# 997   998          Step Up 2: The Streets       Drama,Music,Romance
# 998   999                    Search Party          Adventure,Comedy
# 999  1000                      Nine Lives     Comedy,Family,Fantasy
#
#                                            Description            Director  \
# 990  An origins story centered on the centuries-old...  Patrick Tatopoulos
# ...

# %% [markdown]
# FIND SHAPE OF OUR DATASET (NUMBER OF ROWS AND NUMBERS OF COLUMNS(

# %%
data.shape
# Out:
# (1000, 12)

# %%
print ("Number of Rows", data.shape[0])
print("Number of columns", data.shape[1])
# Out:
# Number of Rows 1000
# Number of columns 12

# %% [markdown]
# GETTING INFORMATION ABOUT OUR DATASET LIKE TOTAL NUMBER ROWS, TOTAL NUMBER OF COLIMNS, DATATYPES OF EACH COLUMN AND MEMORY REQUIREMENT

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Rank                1000 non-null   int64
#  1   Title               1000 non-null   object
#  2   Genre               1000 non-null   object
#  3   Description         1000 non-null   object
#  4   Director            1000 non-null   object
#  5   Actors              1000 non-null   object
#  6   Year                1000 non-null   int64
#  7   Runtime (Minutes)   1000 non-null   int64
#  8   Rating              1000 non-null   float64
#  9   Votes               1000 non-null   int64
#  10  Revenue (Millions)  872 non-null    float64
#  11  Metascore           936 non-null    float64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 93.9+ KB

# %% [markdown]
# CHECK MISSING VALUES IN THE DATASET

# %%
print("Any missing values?", data.isnull().values.any())
# Out:
# Any missing values? True

# %%
data.isnull().sum()
# Out:
# Rank                    0
# Title                   0
# Genre                   0
# Description             0
# Director                0
# Actors                  0
# Year                    0
# Runtime (Minutes)       0
# Rating                  0
# Votes                   0
# Revenue (Millions)    128
# Metascore              64
# dtype: int64

# %%
sns.heatmap(data.isnull())
# Out:
# <Axes: >

# %%
per_missing = data.isnull().sum()*100/len(data)
per_missing
# Out:
# Rank                   0.0
# Title                  0.0
# Genre                  0.0
# Description            0.0
# Director               0.0
# Actors                 0.0
# Year                   0.0
# Runtime (Minutes)      0.0
# Rating                 0.0
# Votes                  0.0
# Revenue (Millions)    12.8
# Metascore              6.4
# dtype: float64

# %% [markdown]
# DROP ALL THE MISSING VALUE

# %%
data.dropna(axis=0,)
# Out:
#      Rank                     Title                     Genre  \
# 0       1   Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2                Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                     Split           Horror,Thriller
# 3       4                      Sing   Animation,Comedy,Family
# 4       5             Suicide Squad  Action,Adventure,Fantasy
# ..    ...                       ...                       ...
# 993   994  Resident Evil: Afterlife   Action,Adventure,Horror
# 994   995                 Project X                    Comedy
# 996   997           Hostel: Part II                    Horror
# 997   998    Step Up 2: The Streets       Drama,Music,Romance
# 999  1000                Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %% [markdown]
# Check for Duplicate data

# %%
dup_data=data.duplicated()

# %%
print("Arc there any duplicate values?", dup_data)
# Out:
# Arc there any duplicate values? 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Length: 1000, dtype: bool

# %%
data=data.drop_duplicates()
data
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %% [markdown]
# GET OVERALL STATISTICS ABOUT THE DATA FRAME

# %%
data.describe(include='all')
# Out:
#                Rank     Title                    Genre  \
# count   1000.000000      1000                     1000
# unique          NaN       999                      207
# top             NaN  The Host  Action,Adventure,Sci-Fi
# freq            NaN         2                       50
# mean     500.500000       NaN                      NaN
# std      288.819436       NaN                      NaN
# min        1.000000       NaN                      NaN
# 25%      250.750000       NaN                      NaN
# 50%      500.500000       NaN                      NaN
# 75%      750.250000       NaN                      NaN
# max     1000.000000       NaN                      NaN
#
#                                               Description      Director  \
# count                                                1000          1000
# unique                                               1000           644
# top     A stuffy businessman finds himself trapped ins...  Ridley Scott
# ...

# %% [markdown]
# DISPLAY TITLE OF THE MOVIE HAVING RUNTIME >=180 MIN.

# %%
data.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
data[data['Runtime (Minutes)']>=180]['Title']
# Out:
# 82     The Wolf of Wall Street
# 88           The Hateful Eight
# 311             La vie d'Adèle
# 828                 Grindhouse
# 965              Inland Empire
# Name: Title, dtype: object

# %% [markdown]
# IN WHICH YEAR THERE WAS THE HIGHEST AVERAGE VOTING ?

# %%
data.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
data.groupby('Year') ['Votes'].mean().sort_values(ascending=False)
# Out:
# Year
# 2012    285226.093750
# 2008    275505.384615
# 2006    269289.954545
# 2009    255780.647059
# 2010    252782.316667
# 2007    244331.037736
# 2011    240790.301587
# 2013    219049.648352
# 2014    203930.224490
# 2015    115726.220472
# 2016     48591.754209
# Name: Votes, dtype: float64

# %%
sns.barplot(x='Year', y='Votes', data=data)
plt.title("Votes By Year")
plt.show()

# %% [markdown]
# IN WHICH YEAR THERE WAS THE HIGHEST AVERAGE REVENUE ?

# %%
data.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
data.groupby('Year') ['Revenue (Millions)'].mean().sort_values(ascending=False)
# Out:
# Year
# 2009    112.601277
# 2012    107.973281
# 2010    105.081579
# 2008     99.082745
# 2007     87.882245
# 2011     87.612258
# 2013     87.121818
# 2006     86.296667
# 2014     85.078723
# 2015     78.355044
# 2016     54.690976
# Name: Revenue (Millions), dtype: float64

# %%
sns.barplot(x='Year', y='Revenue (Millions)', data=data)
plt.title("Revenue By Year")
plt.show()

# %% [markdown]
# FIND AVERAGE RATING FOR EACH DIRECTOR

# %%
data.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
data.groupby('Director')['Rating'].mean().sort_values(ascending=False)
# Out:
# Director
# Nitesh Tiwari                       8.80
# Christopher Nolan                   8.68
# Olivier Nakache                     8.60
# Makoto Shinkai                      8.60
# Florian Henckel von Donnersmarck    8.50
#                                     ...
# Micheal Bafaro                      3.50
# Jonathan Holbrook                   3.20
# Shawn Burkett                       2.70
# James Wong                          2.70
# Jason Friedberg                     1.90
# Name: Rating, Length: 644, dtype: float64

# %% [markdown]
# DISPLAY TOP 10 LENGTHY MOVIES TITLE AND RUNTIME

# %%
data.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
top10_len=data.nlargest(10, 'Runtime (Minutes)') [['Title', 'Runtime (Minutes)']]\
.set_index('Title')

# %%
top10_len
# Out:
#                                           Runtime (Minutes)
# Title
# Grindhouse                                              191
# The Hateful Eight                                       187
# The Wolf of Wall Street                                 180
# La vie d'Adèle                                          180
# Inland Empire                                           180
# Cloud Atlas                                             172
# 3 Idiots                                                170
# Interstellar                                            169
# Pirates of the Caribbean: At World's End                169
# The Hobbit: An Unexpected Journey                       169

# %%
sns.barplot(x='Runtime (Minutes)', y=top10_len.index, data=top10_len)
# Out:
# <Axes: xlabel='Runtime (Minutes)', ylabel='Title'>

# %% [markdown]
# DISPLAY NUMBER OF MOVIES PER YEAR

# %%
data.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
data['Year'].value_counts()
# Out:
# Year
# 2016    297
# 2015    127
# 2014     98
# 2013     91
# 2012     64
# 2011     63
# 2010     60
# 2007     53
# 2008     52
# 2009     51
# 2006     44
# Name: count, dtype: int64

# %%
sns.countplot(x='Year', data=data)
plt.title("Number of Movies Per Year")
plt.show()

# %% [markdown]
# FIND MOST POPULAR MOVIE TITLE (HIGHEST REVENUE)

# %%
data.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
data[data['Revenue (Millions)'].max()==data['Revenue (Millions)']]['Title']
# Out:
# 50    Star Wars: Episode VII - The Force Awakens
# Name: Title, dtype: object

# %% [markdown]
# DISPLAY TOP 10 HIGHEST RATED MOVIE TITLE AND ITS DIRECTORS

# %%
data.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
top10_len=data.nlargest(10, 'Rating') [['Title', 'Rating', 'Director']]\
.set_index('Title')

# %%
top10_len
# Out:
#                        Rating           Director
# Title
# The Dark Knight           9.0  Christopher Nolan
# Inception                 8.8  Christopher Nolan
# Dangal                    8.8      Nitesh Tiwari
# Interstellar              8.6  Christopher Nolan
# Kimi no na wa             8.6     Makoto Shinkai
# The Intouchables          8.6    Olivier Nakache
# The Prestige              8.5  Christopher Nolan
# The Departed              8.5    Martin Scorsese
# The Dark Knight Rises     8.5  Christopher Nolan
# Whiplash                  8.5    Damien Chazelle

# %%
sns.barplot(x='Rating', y=top10_len.index, data=top10_len, hue='Director',dodge=False)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0)

# %% [markdown]
# DISPLAY TOP 10 HIGHEST REVENUE MOVIETITLES

# %%
data.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
data.nlargest(10, 'Revenue (Millions)') ['Title']
# Out:
# 50     Star Wars: Episode VII - The Force Awakens
# 87                                         Avatar
# 85                                 Jurassic World
# 76                                   The Avengers
# 54                                The Dark Knight
# 12                                      Rogue One
# 119                                  Finding Dory
# 94                        Avengers: Age of Ultron
# 124                         The Dark Knight Rises
# 578               The Hunger Games: Catching Fire
# Name: Title, dtype: object

# %%
top_10=data.nlargest(10,'Revenue (Millions)') [['Title','Revenue (Millions)']].\
set_index('Title')

# %%
top_10
# Out:
#                                             Revenue (Millions)
# Title
# Star Wars: Episode VII - The Force Awakens              936.63
# Avatar                                                  760.51
# Jurassic World                                          652.18
# The Avengers                                            623.28
# The Dark Knight                                         533.32
# Rogue One                                               532.17
# Finding Dory                                            486.29
# Avengers: Age of Ultron                                 458.99
# The Dark Knight Rises                                   448.13
# The Hunger Games: Catching Fire                         424.65

# %%
sns.barplot(x='Revenue (Millions)', y=top_10.index, data=top_10)
plt.title("Top 10 Highest Revenue Movies Titles")
plt.show()

# %% [markdown]
# FIND AVERAGE RATING OF MOVIES YEAR WISE

# %%
data.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
data.groupby('Year') ['Rating'].mean().sort_values(ascending=False)
# Out:
# Year
# 2007    7.133962
# 2006    7.125000
# 2009    6.960784
# 2012    6.925000
# 2011    6.838095
# 2014    6.837755
# 2010    6.826667
# 2013    6.812088
# 2008    6.784615
# 2015    6.602362
# 2016    6.436700
# Name: Rating, dtype: float64

# %% [markdown]
# DOES RATING AFFECT THE REVENUE

# %%
data.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
sns.scatterplot(x='Rating', y='Revenue (Millions)', data=data)
# Out:
# <Axes: xlabel='Rating', ylabel='Revenue (Millions)'>

# %% [markdown]
# CALSSIFY MOVIES ON RATING [EXCELLENT, GOOD, AVERAGE]

# %%
data.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
def rating(rating):
  if rating>=7.0:
    return "Excellent"
  elif rating>=6.0:
      return "Good"
  else:
    return "Average"

# %%
data['rating_cat']=data['Rating'].apply(rating)

# %%
data.head()
# Out:
#    Rank                    Title                     Genre  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
# 2     3                    Split           Horror,Thriller
# 3     4                     Sing   Animation,Comedy,Family
# 4     5            Suicide Squad  Action,Adventure,Fantasy
#
#                                          Description              Director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# 2  Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 3  In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 4  A secret government agency recruits some of th...            David Ayer
#
#                                               Actors  Year  Runtime (Minutes)  \
# ...

# %% [markdown]
# COUNT NUMBER OF ACTION MOVIES

# %%
data.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore', 'rating_cat'],
#       dtype='object')

# %%
data['Genre'].dtype
# Out:
# dtype('O')

# %%
len(data[data['Genre'].str.contains('Action', case=False)])
# Out:
# 303

# %% [markdown]
# FIND UNIQUE VALUES FROM GENRE

# %%
data.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore', 'rating_cat'],
#       dtype='object')

# %%
data['Genre']
# Out:
# 0       Action,Adventure,Sci-Fi
# 1      Adventure,Mystery,Sci-Fi
# 2               Horror,Thriller
# 3       Animation,Comedy,Family
# 4      Action,Adventure,Fantasy
#                  ...
# 995         Crime,Drama,Mystery
# 996                      Horror
# 997         Drama,Music,Romance
# 998            Adventure,Comedy
# 999       Comedy,Family,Fantasy
# Name: Genre, Length: 1000, dtype: object

# %%
list1=[]
for value in data['Genre']:
  list1.append(value.split(','))

# %%
list1
# Out:
# [['Action', 'Adventure', 'Sci-Fi'],
#  ['Adventure', 'Mystery', 'Sci-Fi'],
#  ['Horror', 'Thriller'],
#  ['Animation', 'Comedy', 'Family'],
#  ['Action', 'Adventure', 'Fantasy'],
#  ['Action', 'Adventure', 'Fantasy'],
#  ['Comedy', 'Drama', 'Music'],
#  ['Comedy'],
#  ['Action', 'Adventure', 'Biography'],
#  ['Adventure', 'Drama', 'Romance'],
#  ['Adventure', 'Family', 'Fantasy'],
#  ['Biography', 'Drama', 'History'],
#  ['Action', 'Adventure', 'Sci-Fi'],
#  ['Animation', 'Adventure', 'Comedy'],
#  ['Action', 'Comedy', 'Drama'],
#  ['Animation', 'Adventure', 'Comedy'],
#  ['Biography', 'Drama', 'History'],
#  ['Action', 'Thriller'],
#  ['Biography', 'Drama'],
#  ['Drama', 'Mystery', 'Sci-Fi'],
#  ['Adventure', 'Drama', 'Thriller'],
#  ['Drama'],
#  ['Crime', 'Drama', 'Horror'],
#  ['Animation', 'Adventure', 'Comedy'],
#  ['Action', 'Adventure', 'Sci-Fi'],
#  ['Comedy'],
#  ['Action', 'Adventure', 'Drama'],
#  ['Horror', 'Thriller'],
#  ['Comedy'],
# ...

# %%
one_d=[]
for item in list1:
  for item1 in item:
    one_d.append(item1)

# %%
uni_list=[]
for item in one_d:
  if item not in uni_list:
    uni_list.append(item)

# %%
uni_list
# Out:
# ['Action',
#  'Adventure',
#  'Sci-Fi',
#  'Mystery',
#  'Horror',
#  'Thriller',
#  'Animation',
#  'Comedy',
#  'Family',
#  'Fantasy',
#  'Drama',
#  'Music',
#  'Biography',
#  'Romance',
#  'History',
#  'Crime',
#  'Western',
#  'War',
#  'Musical',
#  'Sport']

# %% [markdown]
# HOW MANY FILMS OF EACH GENRE WERE MADE ?

# %%
one_d=[]
for item in list1:
  for item1 in item:
    one_d.append(item1)

# %%
one_d
# Out:
# ['Action',
#  'Adventure',
#  'Sci-Fi',
#  'Adventure',
#  'Mystery',
#  'Sci-Fi',
#  'Horror',
#  'Thriller',
#  'Animation',
#  'Comedy',
#  'Family',
#  'Action',
#  'Adventure',
#  'Fantasy',
#  'Action',
#  'Adventure',
#  'Fantasy',
#  'Comedy',
#  'Drama',
#  'Music',
#  'Comedy',
#  'Action',
#  'Adventure',
#  'Biography',
#  'Adventure',
#  'Drama',
#  'Romance',
#  'Adventure',
#  'Family',
#  'Fantasy',
#  'Biography',
#  'Drama',
#  'History',
#  'Action',
#  'Adventure',
#  'Sci-Fi',
#  'Animation',
#  'Adventure',
#  'Comedy',
#  'Action',
#  'Comedy',
#  'Drama',
#  'Animation',
#  'Adventure',
#  'Comedy',
#  'Biography',
#  'Drama',
#  'History',
#  'Action',
#  'Thriller',
#  'Biography',
#  'Drama',
#  'Drama',
#  'Mystery',
#  'Sci-Fi',
#  'Adventure',
#  'Drama',
#  'Thriller',
#  'Drama',
#  'Crime',
#  'Drama',
#  'Horror',
#  'Animation',
#  'Adventure',
#  'Comedy',
#  'Action',
#  'Adventure',
#  'Sci-Fi',
#  'Comedy',
#  'Action',
#  'Adventure',
# ...

# %%
from collections import Counter

# %%
Counter(one_d)
# Out:
# Counter({'Action': 303,
#          'Adventure': 259,
#          'Sci-Fi': 120,
#          'Mystery': 106,
#          'Horror': 119,
#          'Thriller': 195,
#          'Animation': 49,
#          'Comedy': 279,
#          'Family': 51,
#          'Fantasy': 101,
#          'Drama': 513,
#          'Music': 16,
#          'Biography': 81,
#          'Romance': 141,
#          'History': 29,
#          'Crime': 150,
#          'Western': 7,
#          'War': 13,
#          'Musical': 5,
#          'Sport': 18})

# %%
#Loaded the dataset: The IMDB-Movie-Data.csv file was loaded into a pandas DataFrame.

#Explored the data: Displayed the head and tail of the dataset, checked its shape and information, and identified missing values using isnull() and a heatmap.

#Handled missing values: Calculated the percentage of missing values and dropped rows with missing values.

#Checked for duplicates: Identified and dropped any duplicate rows.
#Descriptive statistics: Obtained overall statistics about the DataFrame using describe().

#Analyzed movie runtimes: Found the titles of movies with a runtime of 180 minutes or more and displayed the top 10 longest movies with their runtimes.

#Analyzed votes and revenue by year: Grouped the data by year to find the highest average votes and revenue, and visualized these findings using bar plots.

#Analyzed ratings by director: Grouped the data by director to find the average rating for each director.

#Analyzed top-rated movies: Displayed the top 10 highest-rated movie titles and their directors, visualizing this with a bar plot.

#Analyzed top-revenue movies: Displayed the top 10 highest revenue movie titles and visualized this with a bar plot.

#Analyzed average rating by year: Grouped the data by year to find the average rating.

#Investigated the relationship between rating and revenue: Created a scatter plot to visualize if rating affects revenue.

#Classified movies by rating: Created a new column 'rating_cat' to classify movies into 'Excellent', 'Good', and 'Average' based on their rating.

#Counted action movies: Counted the number of movies in the 'Action' genre.

#Found unique genres: Extracted all unique genres from the dataset.

#Counted movies per genre: Counted the number of movies for each genre.
